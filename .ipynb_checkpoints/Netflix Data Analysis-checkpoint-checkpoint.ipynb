# %% [markdown]
# # 3.Chargez le dataset

# %%
import pandas as pd
df = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# # 4.Affichez un aperçu du DataFrame

# %% [markdown]
# afficher ses 5 premières observations

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# afficher les 5 dernières observations

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# # 5.Affichez les informations du DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # 6.Affichez la dimensionnalité du DataFrame

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# # 7.Affichez les colonnes du DataFrame

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # 8.Affichez le type des différentes colonnes du DataFrame

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# # 9.Y a-t-il des données manquantes ? Identifiez la proportion en pourcentage

# %%
df.isnull().mean() * 100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %% [markdown]
# # 10.À l’aide de la librairie Missingno. Affichez un graphique représentatif de la proportion des données manquantes

# %%
import missingno as msno
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# # 11.Affichez une observation aléatoire du DataFrame

# %%
df.sample()
# Out:
#      show_id   type            title     director  \
# 4345   s4346  Movie  Once a Gangster  Felix Chong
#
#                                                    cast    country  \
# 4345  Ekin Cheng, Jordan Chan, Alex Fong, Michelle Y...  Hong Kong
#
#             date_added  release_year rating duration  \
# 4345  December 1, 2018          2010  TV-MA   95 min
#
#                                               listed_in  \
# 4345  Action & Adventure, Comedies, International Mo...
#
#                                             description
# 4345  Two former triads are tapped to run in an elec...

# %% [markdown]
# # 12.Affichez toutes les informations de l’œuvre “Catch Me If You Can”

# %%
print(df.loc[df['title'] == 'Catch Me If You Can'])
# Out:
#     show_id   type                title          director  \
# 329    s330  Movie  Catch Me If You Can  Steven Spielberg
#
#                                                   cast                country  \
# 329  Leonardo DiCaprio, Tom Hanks, Christopher Walk...  United States, Canada
#
#          date_added  release_year rating duration listed_in  \
# 329  August 1, 2021          2002  PG-13  142 min    Dramas
#
#                                            description
# 329  An FBI agent makes it his mission to put cunni...

# %% [markdown]
# # 13.Film le plus récent du dataset

# %%
df_films = df[df['type'] == 'Movie']
film_le_plus_recent = df_films.sort_values(by='date_added', ascending=False).iloc[0]
print(film_le_plus_recent['title'])
# Out:
# Blood Brothers: Malcolm X & Muhammad Ali

# %% [markdown]
# # 14.Série la plus récente du dataset

# %%
df_series = df[df['type'] == 'TV Show']
serie_la_plus_recente = df_series.sort_values(by='date_added', ascending=False).iloc[0]
print(serie_la_plus_recente['title'])
# Out:
# Mighty Raju

# %% [markdown]
# # 15.Modification de la variable date_added

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
print(df[df['date_added'].isnull()]['date_added'])
print(df.dtypes)
# Out:
# 6066   NaT
# 6079   NaT
# 6174   NaT
# 6177   NaT
# 6213   NaT
#         ..
# 8539   NaT
# 8557   NaT
# 8684   NaT
# 8712   NaT
# 8755   NaT
# Name: date_added, Length: 98, dtype: datetime64[ns]
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %% [markdown]
# # 16.Modification de la variable duration

# %%
df['duration_min'] = pd.to_numeric(df['duration'].str.replace(' min', ''), errors='coerce')
df['duration_seasons'] = pd.to_numeric(df['duration'].str.replace(' Seasons', ''), errors='coerce')
print(df[['duration_min', 'duration_seasons']])
# Out:
#       duration_min  duration_seasons
# 0             90.0               NaN
# 1              NaN               2.0
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               2.0
# ...            ...               ...
# 8802         158.0               NaN
# 8803           NaN               2.0
# 8804          88.0               NaN
# 8805          88.0               NaN
# 8806         111.0               NaN
#
# [8807 rows x 2 columns]

# %% [markdown]
# # 17.Durée des séries

# %%
df.loc[df['type'] == 'TV Show', 'duration'] = df.loc[df['type'] == 'TV Show', 'duration'].fillna('0')

df.loc[df['type'] == 'TV Show', 'duration'] = df.loc[df['type'] == 'TV Show', 'duration'].fillna('0')

print(df['duration'])
# Out:
# 0          90 min
# 1       2 Seasons
# 2        1 Season
# 3        1 Season
# 4       2 Seasons
#           ...
# 8802      158 min
# 8803    2 Seasons
# 8804       88 min
# 8805       88 min
# 8806      111 min
# Name: duration, Length: 8807, dtype: object

# %% [markdown]
# # 18.Modification de la variable listed_in

# %%
df['listed_in'] = df['listed_in'].apply(lambda x: str(x).split(', ') if pd.notnull(x) else x)

print(df['listed_in'].head())
# Out:
# 0                                      [Documentaries]
# 1    [International TV Shows, TV Dramas, TV Mysteries]
# 2    [Crime TV Shows, International TV Shows, TV Ac...
# 3                             [Docuseries, Reality TV]
# 4    [International TV Shows, Romantic TV Shows, TV...
# Name: listed_in, dtype: object

# %% [markdown]
# # 19.Valeurs uniques des variables

# %%
def afficher_valeurs_uniques(df, colonne):
    valeurs_uniques = df['country'].unique()[:10]
    print("Les 10 premières valeurs uniques pour 'country' sont :")
    for valeur in valeurs_uniques:
        print(valeur)   
        print("\n")

colonnes = ['type', 'country', 'release_year', 'rating', 'listed_in']
for colonne in colonnes:
    afficher_valeurs_uniques(df, colonne)
# Out:
# Les 10 premières valeurs uniques pour 'country' sont :
# United States
#
#
# South Africa
#
#
# nan
#
#
# India
#
#
# United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia
#
#
# United Kingdom
#
#
# Germany, Czech Republic
#
#
# Mexico
#
#
# Turkey
#
#
# Australia
#
#
# Les 10 premières valeurs uniques pour 'country' sont :
# United States
#
#
# South Africa
#
#
# nan
#
#
# India
#
#
# United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia
#
#
# United Kingdom
#
#
# Germany, Czech Republic
#
#
# Mexico
#
#
# Turkey
#
#
# Australia
#
#
# Les 10 premières valeurs uniques pour 'country' sont :
# United States
#
#
# South Africa
#
#
# nan
#
#
# India
#
#
# United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia
#
#
# United Kingdom
#
#
# Germany, Czech Republic
#
#
# Mexico
#
#
# Turkey
#
#
# Australia
#
#
# Les 10 premières valeurs uniques pour 'country' sont :
# United States
#
#
# South Africa
#
#
# nan
#
#
# India
#
#
# ...

# %% [markdown]
# # 20.Director ayant produit plus d’une oeuvre

# %%
print(df['director'].value_counts() > 1)
# Out:
# director
# Rajiv Chilaka                      True
# Raúl Campos, Jan Suter             True
# Marcus Raboy                       True
# Suhas Kadav                        True
# Jay Karas                          True
#                                   ...
# Raymie Muzquiz, Stu Livingston    False
# Joe Menendez                      False
# Eric Bross                        False
# Will Eisenberg                    False
# Mozez Singh                       False
# Name: count, Length: 4528, dtype: bool

# %% [markdown]
# # 21.Année avec le plus de films ajoutés au catalogue de Netflix

# %%
print(df[df['type'] == 'Movie']['release_year'].value_counts().idxmax())
# Out:
# 2017

# %% [markdown]
# # 22.Année avec le plus de series ajoutés au catalogue de Netflix

# %%
print(df[df['type'] == 'TV Show']['release_year'].value_counts().idxmax())
# Out:
# 2020

# %% [markdown]
# # 23.Visualisez vos données à l’aide des différentes librairies de Matplotlib, Seaborn ou Plotly :

# %% [markdown]
# a. La répartition du type d'oeuvres du dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='type', data=df)
plt.title('Répartition du type d\'oeuvres')
plt.show()

# %% [markdown]
# b. La répartition des oeuvres en fonction des pays du dataset

# %%
# Compter le nombre d'oeuvres par pays
oeuvres_par_pays = df['country'].value_counts()

# Sélectionner uniquement les 10 premiers pays
top10_pays = oeuvres_par_pays.head(10)

# Créer le graphique
plt.figure(figsize=(10,6))
sns.barplot(x=top10_pays.index, y=top10_pays.values)
plt.title('Répartition des oeuvres par pays pour les 10 premiers pays')
plt.xlabel('country')
plt.ylabel('Nombre d\'oeuvres')
plt.xticks(rotation=90)  # Rotation des labels de l'axe x pour une meilleure lisibilité
plt.show()

# %% [markdown]
# c. La répartition des années du dataset

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['release_year'], kde=False, bins=30)
plt.title('Répartition des années')
plt.show()

# %% [markdown]
# d. La répartition des ratings du dataset

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], kde=False, bins=30)
plt.title('Répartition des ratings')
plt.show()

# %% [markdown]
# e. La répartition de la durée des films du dataset

# %%
df.loc[df['type'] == 'Movie', 'duration'] = df.loc[df['type'] == 'Movie', 'duration'].fillna(0)
df.loc[df['type'] == 'Movie', 'duration'] = df.loc[df['type'] == 'Movie', 'duration'].apply(lambda x: int(x.replace(' min', '')) if isinstance(x, str) else x)
bins = range(0, int(df.loc[df['type'] == 'Movie', 'duration'].max()) + 31, 30)
plt.figure(figsize=(18,5))
movie_durations = df.loc[df['type'] == 'Movie']['duration']
duration_counts = pd.cut(movie_durations, bins=bins, right=False).value_counts().sort_index()
duration_counts.plot(kind='bar', color= 'blue' )
plt.title('Répartition des durées des films par tranche de 30 minutes')
plt.xlabel('Durée en minutes')
plt.ylabel('Nombre de Films')
plt.xticks(range(len(duration_counts)), [f'{i.left}-{i.right-1}' for i in duration_counts.index], rotation=45)
plt.grid(False)
plt.show()

# %% [markdown]
# f. La répartition de la durée des séries du dataset

# %%
import re
df.loc[df['type'] == 'TV Show', 'duration'] = df.loc[df['type'] == 'TV Show', 'duration'].fillna(0)
df.loc[df['type'] == 'TV Show', 'duration'] = df.loc[df['type'] == 'TV Show', 'duration'].apply(lambda x: int(re.search(r'\d+', str(x)).group()) if re.search(r'\d+', str(x)) else x)
plt.figure(figsize=(18,5))
tv_show_durations = df.loc[df['type'] == 'TV Show']['duration']
duration_counts = tv_show_durations.value_counts().sort_index()
duration_counts.plot(kind='bar', color= 'blue')
plt.title('Répartition des durées des séries')
plt.xlabel('Nombre de saisons')
plt.ylabel('Nombre de séries')
plt.grid(False)
plt.show()

# %% [markdown]
# g. La répartition des genres d’œuvres du dataset
